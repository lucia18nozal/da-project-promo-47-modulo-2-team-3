# %%
import requests
import pandas as pd
# !pip install spotipy --upgrade
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
# Out:
# Requirement already satisfied: spotipy in c:\users\hyena\anaconda3\lib\site-packages (2.25.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\hyena\anaconda3\lib\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\users\hyena\anaconda3\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\hyena\anaconda3\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hyena\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hyena\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hyena\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
client_id = "271ad807efbf45b99baaebabd0507126"
client_secret = "4b81c2cfcec5455eb8af9042f5d50d91"

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret) #Para llamar a la Api
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q="genre:rock year:2020", type='track', limit=50, offset=0) #Buscar dentro de la api (lo que hay entre paréntesis)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
# ejemplos yanelis
cancion_con_todo = datos['tracks']['items'][1]
cancion_con_todo
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HcwFjNelS49kFbfvMxQYw'},
#     'href': 'https://api.spotify.com/v1/artists/2HcwFjNelS49kFbfvMxQYw',
#     'id': '2HcwFjNelS49kFbfvMxQYw',
#     'name': 'Robbie Williams',
#     'type': 'artist',
#     'uri': 'spotify:artist:2HcwFjNelS49kFbfvMxQYw'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1OlowpqFwtb6NiZVJ1Wmk4'},
#   'href': 'https://api.spotify.com/v1/albums/1OlowpqFwtb6NiZVJ1Wmk4',
#   'id': '1OlowpqFwtb6NiZVJ1Wmk4',
#   'images': [{'height': 640,
#     'width': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731f4545a20b2231cda6272c05'},
#    {'height': 300,
#     'width': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021f4545a20b2231cda6272c05'},
#    {'height': 64,
#     'width': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511f4545a20b2231cda6272c05'}],
#   'is_playable': True,
#   'name': 'The Christmas Present (Deluxe)',
#   'release_date': '2020-11-20',
#   'release_date_precision': 'day',
#   'total_tracks': 29,
#   'type': 'album',
#   'uri': 'spotify:album:1OlowpqFwtb6NiZVJ1Wmk4'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HcwFjNelS49kFbfvMxQYw'},
#    'href': 'https://api.spotify.com/v1/artists/2HcwFjNelS49kFbfvMxQYw',
#    'id': '2HcwFjNelS49kFbfvMxQYw',
#    'name': 'Robbie Williams',
#    'type': 'artist',
#    'uri': 'spotify:artist:2HcwFjNelS49kFbfvMxQYw'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 2,
#  'duration_ms': 203438,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBPS62000001'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/7jBePLCZlKuEUc3rSc6izU'},
#  'href': 'https://api.spotify.com/v1/tracks/7jBePLCZlKuEUc3rSc6izU',
#  'id': '7jBePLCZlKuEUc3rSc6izU',
#  'is_local': False,
#  'is_playable': True,
#  'name': "Can't Stop Christmas",
#  'popularity': 67,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:7jBePLCZlKuEUc3rSc6izU'}

# %%
#ejemplos yanelis
cancion_con_lo_necesito={
    "nombre_cancion": cancion_con_todo['name'],
    "nombre_artista": cancion_con_todo['artists'][0]['name'],
    'genre': "rock",
    "type": cancion_con_todo['type'],
    "year": cancion_con_todo['album']['release_date'][:4]
}
cancion_con_lo_necesito
# Out:
# {'nombre_cancion': "Can't Stop Christmas",
#  'nombre_artista': 'Robbie Williams',
#  'genre': 'rock',
#  'type': 'track',
#  'year': '2020'}

# %%
#ejemplo yanelis
genres = ["poprock","soul","classic","reggae"]
year_start = 2000
year_end = 2005

lista_canciones_albumes = [] 
lista_artistas = []

# %%
for genre in genres: 
    print(f"Extrayendo datos del genero{genre}")
    datos = sp.search(q=f"genre:{genre} year:{year_start-year_end}", type='track, album', limit=50, offset=0)
    for item in datos['tracks']['items']: 
        
        #crear el objeto (canciones)
        #añadir a la lista de canciones
        #añdiendo el nombre artista a la lista de artistas
    for item in datos["albums"]['items']: 
        
    #crear el objeto(canciones)
    #añadir a la lista de canciones
    #añadiendo el nobre a la lista de artistas

# %%
#guardar en un csv 
df= pd.DataFrame(lista_canciones_albumes)
df.to_csv("lista_de_canciones.csv");
#se hace lo mismo para guardar el listado de artistas en un csv, verificar que el nombre de los artistas sea unico
